# %%
from machine_learning_jh.data import Circles

circle_generator = Circles(n_points_per_class=200, n_classes=3, noise_std=0.3)
features, target = circle_generator.generate()

# %%
import matplotlib.pyplot as plt

plt.scatter(features[:, 0], features[:, 1], c=target)
plt.show()
